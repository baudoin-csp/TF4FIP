# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 13
#      11 # Check if the row 'diff_q0_q8' exists in the index
#      12 if 'diff_q0_q8' not in df_chronos.index:
# ---> 13     raise ValueError("Row 'diff_q0_q8' not found in the dataframe index. Check the CSV file structure.")
#      15 # 1. Rename the row from 'diff_q0_q8' to 'diff_q8_q0'
#      16 df_chronos.rename(index={'diff_q0_q8': 'diff_q8_q0'}, inplace=True)
#
# ValueError: Row 'diff_q0_q8' not found in the dataframe index. Check the CSV file structure.
