# %%
import pandas as pd

# List of file names to truncate
file_names = [
    "analysis/test_future_data/data_2023_2025_chronos_final_copy.csv",
    "analysis/test_future_data/data_2023_2025_moirai_final_copy.csv",
    "analysis/test_future_data/data_2023_2025_time_moe_final_copy.csv"
]

# Loop over each file, truncate, and overwrite
for file in file_names:
    df = pd.read_csv(file)
    df_truncated = df.head(394)
    df_truncated.to_csv(file, index=False)
    print(f"Overwritten {file} with first 394 rows.")
# Out:
# Overwritten analysis/test_future_data/data_2023_2025_chronos_final_copy.csv with first 394 rows.
# Overwritten analysis/test_future_data/data_2023_2025_moirai_final_copy.csv with first 394 rows.
# Overwritten analysis/test_future_data/data_2023_2025_time_moe_final_copy.csv with first 394 rows.
